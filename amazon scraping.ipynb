# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd 
import numpy as np

# %%
def get_title(soup):
    try:
        title =soup.find("span", attrs={'id':'productTitle'})
        title_value = title.text
        title_string = title_value.strip()
    except AttributeError:
        title_string = ""
    return title_string

# %%
def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'id':'a-icon a-icon-star-small a-star-small-4 aok-align-bottom'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating

# %%
def get_number_of_review(soup):
    try:
        number_of_review = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        number_of_review = ""	

    return number_of_review

# %%
if __name__ == '__main__':
    HEADERS = ({'User-Agent':'', 'Accept-Language': 'en-US, en;q=0.5'})
    URL = "https://www.amazon.in/s?k=speakers&crid=3AWDZLFUO80UK&sprefix=%2Caps%2C251&ref=nb_sb_ss_recent_1_0_recent"

    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[],"rating":[], "reviews":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.in" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_number_of_review(new_soup))
        

    
    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['title'].replace('', np.nan, inplace=True)
    amazon_df = amazon_df.dropna(subset=['title'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
amazon_df
# Out:
#                                                 title              rating  \
# 0   All-New Echo Dot (5th Gen, 2023 release) | Sma...  4.1 out of 5 stars
# 1   SKYBALL Party Pillar 1100, Tower Speaker with ...  5.0 out of 5 stars
# 2   JBL Flip 5 Wireless Portable Bluetooth Speaker...  4.4 out of 5 stars
# 3   AmazonBasics Bluetooth Speaker 5.0 Soundbar wi...  3.7 out of 5 stars
# 4   boAt Stone 352 Bluetooth Speaker with 10W RMS ...  4.0 out of 5 stars
# 5   boAt Stone 180 5W Bluetooth Speaker with Upto ...  4.1 out of 5 stars
# 6   boAt Stone 1208 Bluetooth Speaker with Upto 9 ...  4.2 out of 5 stars
# 7   boAt Stone 352 Bluetooth Speaker with 10W RMS ...  4.0 out of 5 stars
# 8   JBL Go 3, Wireless Ultra Portable Bluetooth Sp...  4.4 out of 5 stars
# 9   Infinity (JBL Fuze Pint, Wireless Ultra Portab...  4.1 out of 5 stars
# 10  JBL Go 2, Wireless Portable Bluetooth Speaker ...  4.3 out of 5 stars
# 11  AmazonBasics Bluetooth Speaker 5.0 Soundbar wi...  3.7 out of 5 stars
# ...
